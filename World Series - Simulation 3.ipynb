# %% [markdown]
# # Baseball World Series Simulation
# ## On average, how many games (out of 7) does it take for a team to World Series?
# * An American League (AL) baseball team is considered to have a 60% chance of beating the National League (NL) team in any given World Series game. A team wins the World Series by being the first to win four individual games.

# %% [markdown]
# ### Individual game
# * Generate a random integer between 1 and 100
#  * #'s 1-60 will represent an American League (AL) team win
#    * 60% chance to win
#  * #'s 61-100 will represent a National League (NL) team win
#    * 40% chance to win

# %%
# Import the numpy package
import numpy as np

# Generate random number between 1-100
single_game = np.random.randint(1,101)

# Test the percentage ranges
if single_game <= 60:
    print("AL Wins")
else:
    print("NL Wins")
# Out:
# NL Wins

# %% [markdown]
# #### Copy and paste code into a function
# * Return a String of the winning division
# * Abstraction!

# %%
# Create function that represents one game being played
def play_single_game():
    # Generate random number between 1-100
    single_game = np.random.randint(1,101)

    # Test the percentage ranges
    if single_game <= 60:
        return("AL Wins")
    else:
        return("NL Wins")

# %%
# Verify your function works correctly
print(play_single_game())
# Out:
# NL Wins

# %% [markdown]
# ### Individual World Series
# * Create two variables for AL and NL win counts
# * While both counts are below 4 wins, play a single game
#   * Update variables appropriately
# * Return a tuple in the form (winning division,total games played)

# %%
# Import the numpy package
import numpy as np

# Create variables
nl_wins = 0
al_wins = 0
        
# While loop
while nl_wins != 4 and al_wins != 4:
    wsg = play_single_game()
    if wsg == "NL Wins":
        nl_wins += 1
    else:
        al_wins += 1

# Total games played before a division reached four wins
total_num_games = nl_wins + al_wins

# Print winner and games
if nl_wins == 4:
    print("NL", total_num_games)
else:
    print("AL", total_num_games)
# Out:
# AL 4

# %% [markdown]
# ## Defining an individual trial
# #### Copy and paste code into a function
# * Return a tuple in the format (winning division, total number of games played)
# * Abstraction!

# %%
# Create function to represent one trial of a World Series 
def play_world_series():
    # Create variables
    nl_wins = 0
    al_wins = 0

    # While loop
    while nl_wins != 4 and al_wins != 4:
        wsg = play_single_game()
        if wsg == "NL Wins":
            nl_wins += 1
        else:
            al_wins += 1

    # Total games played before a division reached four wins
    total_num_games = nl_wins + al_wins

    # Print winner and games
    if nl_wins == 4:
        return("NL", total_num_games)
    else:
        return("AL", total_num_games)

# %%
# Verify
print(play_world_series())
# Out:
# ('NL', 6)

# %% [markdown]
# ### Finding the average number of total games played to win a World Series
# #### Simulate a large number of individual trials of a World Series, analyze the results
# * Create an array to hold your results
# * Create a loop to run 10,000 times
#     * Add results of a single World Series to the array

# %%
# Create variables
ws_results = []

# Create a loop that repeats a large number of trials (World Series), in this case 10,000
for i in range(10000):
    ws = play_world_series()
    ws_results.append(ws)
    
# Print the results
print(ws_results)
# Out:
# [('AL', 6), ('NL', 5), ('NL', 5), ('AL', 7), ('AL', 5), ('NL', 7), ('AL', 4), ('NL', 5), ('AL', 6), ('AL', 5), ('AL', 7), ('NL', 7), ('NL', 6), ('NL', 6), ('AL', 6), ('AL', 7), ('AL', 4), ('AL', 4), ('AL', 4), ('NL', 4), ('AL', 5), ('NL', 7), ('NL', 7), ('AL', 5), ('AL', 4), ('NL', 6), ('AL', 6), ('AL', 7), ('NL', 7), ('NL', 5), ('AL', 6), ('AL', 5), ('AL', 7), ('NL', 5), ('AL', 6), ('AL', 7), ('AL', 5), ('AL', 5), ('AL', 6), ('AL', 6), ('AL', 5), ('AL', 4), ('NL', 6), ('AL', 4), ('AL', 5), ('AL', 7), ('NL', 5), ('AL', 5), ('AL', 6), ('AL', 5), ('AL', 5), ('AL', 5), ('AL', 7), ('NL', 7), ('AL', 7), ('AL', 6), ('NL', 7), ('AL', 5), ('AL', 7), ('NL', 4), ('AL', 5), ('AL', 6), ('NL', 7), ('AL', 6), ('AL', 6), ('AL', 7), ('AL', 6), ('AL', 6), ('NL', 7), ('AL', 6), ('AL', 4), ('AL', 7), ('NL', 5), ('AL', 6), ('AL', 6), ('NL', 6), ('NL', 5), ('AL', 7), ('NL', 6), ('AL', 7), ('AL', 6), ('AL', 5), ('NL', 4), ('AL', 6), ('AL', 5), ('AL', 4), ('AL', 4), ('NL', 5), ('AL', 5), ('NL', 6), ('AL', 4), ('AL', 5), ('AL', 5), ('AL', 5), ('AL', 7), ('AL', 6), ('AL', 7), ('AL', 5), ('NL', 7), ('AL', 7), ('AL', 6), ('AL', 4), ('AL', 6), ('AL', 5), ('AL', 7), ('NL', 7), ('NL', 5), ('NL', 6), ('AL', 6), ('AL', 6), ('AL', 5), ('AL', 4), ('AL', 7), ('AL', 4), ('AL', 6), ('AL', 6), ('AL', 6), ('AL', 5), ('AL', 6), ('AL', 4), ('NL', 7), ('NL', 7), ('AL', 5), ('AL', 4), ('AL', 4), ('AL', 5), ('NL', 7), ('AL', 7), ('AL', 6), ('AL', 6), ('AL', 6), ('AL', 6), ('AL', 5), ('AL', 5), ('AL', 5), ('AL', 4), ('NL', 5), ('NL', 5), ('AL', 5), ('NL', 7), ('NL', 6), ('NL', 5), ('NL', 6), ('AL', 7), ('NL', 5), ('AL', 6), ('AL', 5), ('AL', 7), ('NL', 5), ('AL', 5), ('AL', 5), ('AL', 4), ('AL', 4), ('AL', 6), ('AL', 7), ('AL', 5), ('AL', 6), ('AL', 7), ('AL', 6), ('AL', 6), ('AL', 5), ('NL', 5), ('NL', 6), ('AL', 6), ('AL', 5), ('AL', 6), ('AL', 5), ('NL', 7), ('AL', 7), ('AL', 6), ('AL', 5), ('NL', 7), ('AL', 7), ('AL', 5), ('AL', 4), ('AL', 4), ('NL', 6), ('AL', 7), ('AL', 7), ('NL', 6), ('AL', 4), ('AL', 6), ('NL', 6), ('AL', 4), ('AL', 5), ('NL', 7), ('AL', 6), ('NL', 4), ('NL', 6), ('NL', 6), ('NL', 5), ('AL', 5), ('AL', 7), ('NL', 5), ('AL', 7), ('AL', 5), ('NL', 6), ('AL', 5), ('AL', 6), ('AL', 5), ('NL', 6), ('NL', 7), ('AL', 4), ('AL', 4), ('NL', 6), ('AL', 5), ('AL', 4), ('AL', 5), ('AL', 5), ('AL', 6), ('AL', 5), ('AL', 5), ('AL', 4), ('AL', 5), ('AL', 6), ('NL', 7), ('AL', 4), ('AL', 5), ('NL', 7), ('NL', 6), ('AL', 4), ('AL', 6), ('AL', 7), ('AL', 5), ('AL', 5), ('NL', 5), ('NL', 6), ('NL', 5), ('AL', 7), ('AL', 7), ('NL', 7), ('NL', 7), ('NL', 5), ('AL', 5), ('AL', 6), ('NL', 6), ('AL', 5), ('AL', 4), ('NL', 7), ('AL', 5), ('NL', 7), ('AL', 5), ('AL', 4), ('AL', 4), ('NL', 6), ('AL', 5), ('NL', 7), ('AL', 7), ('AL', 6), ('NL', 7), ('AL', 6), ('AL', 6), ('AL', 4), ('AL', 7), ('AL', 7), ('AL', 4), ('NL', 4), ('AL', 4), ('AL', 6), ('AL', 4), ('NL', 6), ('AL', 5), ('AL', 4), ('AL', 7), ('AL', 5), ('AL', 4), ('AL', 6), ('NL', 7), ('AL', 6), ('NL', 7), ('NL', 7), ('AL', 5), ('AL', 4), ('AL', 4), ('AL', 6), ('NL', 7), ('AL', 7), ('AL', 6), ('AL', 4), ('AL', 5), ('AL', 5), ('NL', 6), ('AL', 5), ('NL', 7), ('NL', 5), ('AL', 7), ('AL', 6), ('AL', 5), ('AL', 7), ('AL', 5), ('NL', 7), ('AL', 5), ('AL', 4), ('AL', 4), ('NL', 5), ('NL', 6), ('AL', 7), ('NL', 7), ('AL', 7), ('NL', 7), ('AL', 4), ('AL', 6), ('NL', 5), ('AL', 5), ('NL', 7), ('AL', 6), ('NL', 6), ('AL', 6), ('NL', 6), ('AL', 6), ('AL', 5), ('NL', 7), ('AL', 4), ('AL', 6), ('AL', 6), ('NL', 5), ('AL', 6), ('AL', 5), ('AL', 6), ('NL', 7), ('NL', 7), ('AL', 6), ('AL', 7), ('AL', 5), ('AL', 6), ('AL', 4), ('AL', 6), ('AL', 6), ('AL', 4), ('AL', 6), ('NL', 7), ('NL', 7), ('NL', 5), ('AL', 7), ('AL', 7), ('AL', 6), ('AL', 6), ('AL', 6), ('AL', 7), ('AL', 5), ('NL', 7), ('NL', 4), ('AL', 7), ('NL', 7), ('AL', 5), ('NL', 5), ('AL', 6), ('AL', 7), ('AL', 5), ('NL', 6), ('AL', 7), ('NL', 7), ('AL', 4), ('AL', 6), ('AL', 7), ('AL', 6), ('AL', 5), ('NL', 7), ('NL', 7), ('AL', 6), ('NL', 5), ('AL', 7), ('AL', 5), ('AL', ...

# %% [markdown]
# ### Analyze the results

# %% [markdown]
# #### Find the counts of each number of total games (How many times did it take 4, 5, 6, 7 games to win?)
# * Create an array to hold the results
# * Loop through each tuple, read second value (total games played)
# * Add the value to array

# %%
# Create variables
total_games_array = []

# Loop through each individual trial within the ws_results array
    # Store second value of the tuple at index 1 (total number of games)
    # Add game total to the total_games_array
for ws_tuple in ws_results:
    num_games = ws_tuple[1]
    total_games_array.append(num_games)

# Print results
print(total_games_array)
# Out:
 4, 5, 7, 6, 5, 5, 7, 4, 7, 6, 6, 6, 5, 6, 4, 6, 7, 5, 6, 6, 5, 6, 6, 7, 6, 5, 7, 7, 4, 5, 6, 6, 6, 5, 5, 7, 7, 6, 6, 6, 5, 5, 6, 5, 5, 7, 5, 6, 7, 5, 5, 7, 5, 5, 5, 7, 6, 4, 4, 5, 7, 6, 4, 7, 4, 6, 7, 5, 7, 4, 6, 4, 6, 4, 6, 7, 4, 5, 5, 6, 6, 5, 7, 5, 5, 5, 5, 6, 7, 6, 7, 4, 5, 6, 5, 4, 4, 7, 5, 6, 6, 7, 7, 6, 7, 4, 7, 6, 4, 6, 5, 4, 6, 7, 7, 7, 5, 6, 6, 6, 6, 7, 6, 5, 5, 7, 5, 7, 7, 6, 5, 6, 7, 7, 6, 4, 6, 7, 7, 7, 7, 6, 6, 6, 7, 4, 5, 4, 5, 6, 5, 6, 6, 6, 7, 5, 7, 7, 6, 6, 7, 7, 6, 5, 7, 5, 6, 4, 5, 6, 7, 6, 6, 6, 7, 6, 6, 7, 7, 5, 5, 5, 7, 5, 7, 7, 6, 6, 6, 5, 6, 4, 6, 5, 4, 6, 7, 7, 5, 5, 4, 7, 5, 6, 5, 7, 6, 4, 5, 6, 6, 5, 7, 4, 6, 4, 5, 4, 5, 6, 5, 7, 5, 5, 7, 5, 6, 7, 6, 7, 4, 4, 6, 6, 7, 5, 7, 7, 4, 5, 7, 7, 5, 4, 5, 5, 7, 4, 7, 6, 4, 5, 7, 6, 7, 5, 4, 6, 5, 5, 7, 6, 4, 6, 7, 7, 7, 4, 6, 6, 7, 4, 5, 6, 7, 4, 4, 5, 5, 5, 5, 5, 6, 5, 6, 7, 4, 6, 7, 6, 7, 6, 7, 5, 5, 5, 6, 6, 6, 6, 4, 6, 4, 4, 5, 4, 5, 4, 7, 5, 6, 5, 4, 5, 6, 6, 6, 6, 6, 5, 5, 4, 5, 4, 7, 7, 7, 5, 7, 4, 4, 7, 5,  ...

# %% [markdown]
# #### Create bins for each total

# %%
# Create the bin
game_bin = np.bincount(total_games_array)

# Print the results
print(game_bin)
# Out:
# [   0    0    0    0 1514 2611 3059 2816]

# %%
# Make sure this adds to 10,000 trials!
print(np.sum(game_bin))
# Out:
# 10000

# %% [markdown]
# #### Calculate the average number of games played in each trial
# * This will represent the average number of games played to win the World Series after 10,000 trials

# %%
# Use np.average(array)
average = np.average(total_games_array)
print(average)
# Out:
# 5.7177

# %% [markdown]
# ### Graph the results

# %% [markdown]
# #### Histogram
# * Frequency chart

# %%
# Import the library
import matplotlib.pyplot as plot
# %matplotlib inline  
# Magic to allow the graph to display directly in this notebook

# Create bins/dividers for your data
bins = [4, 5, 6, 7, 8]

# plot.hist(array, bins, alignment, graph color, border color)
plot.hist(total_games_array, bins, align='left', color='yellow' ,edgecolor='black')
plot.title("Average Total Games Played To Win a World Series")
plot.show()

# %% [markdown]
# #### Pie Chart
# * Percentage chart

# %%
# source: http://matplotlib.org/examples/pie_and_polar_charts/pie_demo_features.html

# Import the library
import matplotlib.pyplot as plot
# %matplotlib inline
# Magic to allow the graph to display directly in this notebook

# Create an array of labels
labels = ["4 Games", "5 Games", "6 Games", "7 Games"]

# Crop the game_bin array to exclude the 0's
    # Only need indices 4 to the end
game_bin = game_bin[4:]

# Explode option
    # 'Slices' appear distanced from the center
        # Larger numbers = further explosion
    # Explode array should be same size as labels and
explode = (0, 0.1, 0, 0)

# Use matplotlib module subplots() to get data for various charts
    # Returns a tuple in the form (figure,axes)
fig1,ax1 = plot.subplots()

# Use axes to create a pie chart
    # ax1.pie(data array, explode array, labels array, starting angle)
ax1.pie(game_bin, explode, labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plot.show()

# %% [markdown]
# # Answer
# * According to our simulation, the average world series is won in approximately 5.7177.

# %% [markdown]
# ## Additional data points
# * How many times did an American League team win the World Series compared to the National League?

# %%
# Create variables
winning_division_array = []

# Loop through each individual World Series within the ws_results array
    # Store first value of the tuple at index 0 (winning division)
    # Add winning division to the winning_division_array
for world_series in ws_results:
    division = world_series[0]
    winning_division_array.append(division)

# Print results
print(winning_division_array)
# Out:
# ['AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'NL', 'AL', 'NL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL ...

# %% [markdown]
# #### Count the totals of NL and AL
# * Loop through each winning division in the array
# * Update a count for each division accordingly

# %%
# Create variables
total_al = 0
total_nl = 0

# Loop through each division in the winning_division_array, update wins
for division in winning_division_array:
    if division == "AL":
        total_al = total_al + 1
    else:
        total_nl = total_nl + 1

# Display results
print("Number NL wins: " + str(total_nl))
print("Number AL wins: " + str(total_al))
# Out:
# Number NL wins: 2936
# Number AL wins: 7064

# %% [markdown]
# ### Don't forget to answer the original question!
# * Answer should be in the form of a complete sentence

# %% [markdown]
# # Answer
# * According to our simulation, the Nation League won 2936 World Series, and the American League won 7064 World Series.
