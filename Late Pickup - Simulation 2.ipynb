# %% [markdown]
# # Simulation Practice - Wait Time
# * Every morning, there is a 15% chance that your friend picks you up late on the way to school.
#
# ## How many school days in a row will typically pass until your friend is late?

# %% [markdown]
# ### Simulating a single day
# * Generate a random integer between 1 and 100
#  * #'s 1-15 represent your friend showing up late
#       * 15% chance
#  * #'s 16-100 represent your friend showing up on time
#       * 85% chance

# %%
# import the numpy package
import numpy as np

# Generate random number between 1-100
single_day = np.random.randint(1,101)

# Test the percentage ranges
if (single_day <= 15):
    print("Late")
else:
    print("On Time")
# Out:
# Late

# %% [markdown]
# #### Copy and paste code into a function
# * Return a String of "Late" or "On Time"
# * Abstraction!

# %%
# Create a function to simulate a single day
def single_day_trial():
    single_day = np.random.randint(1,101)
    if (single_day <= 15):
        return "Late"
    else:
        return "On Time"
print(single_day_trial())
# Out:
# Late

# %% [markdown]
# ### Simulate a single trial until your friend shows up late
# * Create a variable that tracks the number of consecutive days on time
#     * Start at 0!
# * Utilize a "while" loop
#     * While your single day trial returns "On Time", add one to your consecutive days variable
# * Print the variable tracking the number of consecutive days before your friend shows up late

# %%
#Import the numpy package
import numpy as np

# Create variables
consecutive_days = 0

# While loop
while (single_day_trial() == "On Time"):
    consecutive_days += 1
    
# Print results
print(consecutive_days)
# Out:
# 8

# %% [markdown]
# #### Copy and paste code into a function
# * Return the number of consecutive days your friend showed up on time
# * Abstraction!

# %%
# Create a function that simulates a complete single trial
def consecutive_days_trial():
    consecutive_days = 0

    while (single_day_trial() == "On Time"):
        consecutive_days = consecutive_days + 1
    return consecutive_days
print(consecutive_days_trial())
# Out:
# 2

# %% [markdown]
# ### Finding the average number of consecutive days until your friend shows up late
# * Create an array to hold your results
# * Create a loop to run 10000 times
#     * Add result of each consecutive days trial to the array

# %%
# Create variables
consecutive_days_results = []

# Create a loop that repeats a large number of trials, in this case 10000 times
for i in range(10000):
    result = consecutive_days_trial()
    consecutive_days_results.append(result)
    
# Print the results
print(consecutive_days_results)
# Out:
# [1, 4, 6, 1, 2, 6, 11, 14, 2, 7, 15, 0, 2, 3, 0, 3, 5, 6, 5, 4, 12, 5, 6, 8, 1, 9, 1, 16, 1, 8, 3, 1, 3, 16, 5, 6, 13, 0, 0, 6, 7, 10, 1, 13, 6, 2, 0, 2, 17, 10, 0, 4, 3, 8, 2, 1, 2, 9, 4, 1, 4, 26, 8, 5, 11, 2, 10, 1, 5, 3, 5, 20, 8, 10, 0, 4, 0, 0, 2, 0, 17, 2, 3, 0, 15, 7, 4, 1, 4, 17, 17, 0, 2, 19, 3, 10, 0, 0, 1, 0, 2, 9, 2, 11, 4, 0, 1, 0, 3, 6, 7, 21, 0, 7, 5, 16, 1, 6, 1, 6, 13, 15, 5, 4, 0, 3, 9, 1, 2, 3, 4, 11, 1, 2, 1, 2, 8, 1, 11, 4, 5, 3, 3, 13,
 0, 17, 12, 3, 0, 2, 0, 11, 3, 11, 3, 11, 1, 3, 21, 26, 24, 0, 1, 1, 19, 6, 0, 2, 1, 2, 15, 1, 17, 11, 16, 8, 3, 3, 2, 7, 2, 11, 1, 6, 2, 3, 5, 2, 2, 2, 17, 7, 10, 0, 4, 7, 3, 4, 12, 10, 5, 6, 5, 2, 15, 22, 1, 0, 4, 7, 0, 2, 2, 7, 2, 15, 1, 8, 3, 8, 6, 10, 8, 9, 14, 1, 0, 10, 0, 7, 25, 5, 6, 1, 6, 20, 4, 5, 5, 0, 6, 21, 9, 2, 0, 5, 5, 2, 11, 6, 5, 3, 0, 3, 7, 3, 0, 1, 8, 0, 2, 4, 0, 16, 1, 0, 18, 0, 1, 1, 3, 1, 2, 0, 2, 8, 10, 7, 7, 5, 1, 6, 6, 1, 3, 11, 3, 6, 18, 20, 5, 3, 9, 1, 2, 1, 14, ...

# %% [markdown]
# ### Analyze the results

# %% [markdown]
# #### Calculate the sum of all trials in the list

# %%
# Create variables
total_trials = 10000
sum_of_trials = 0

# Loop through each entry, adding it to the sum
for entry in consecutive_days_results:
    sum_of_trials += entry
        
# Print the results
print(sum_of_trials)
# Out:
# 57534

# %% [markdown]
# #### Calculate the average
# * Average = sum of trials / total trials

# %%
# Calculate the average
average = sum_of_trials / total_trials

# Print the results
print(average)
# Out:
# 5.7534

# %% [markdown]
# ### Graph the results

# %%
# Count the results using bincount()
count_consecutive_days = np.bincount(consecutive_days_results)
print(count_consecutive_days)
# Out:
# [1501 1251 1113  886  772  653  574  483  414  344  289  244  229  178
#   164  134  110   96   85   73   49   55   42   41   31   31   24   25
#    15   11   11    9    9    6   13    2    4    8    4    2    2    0
#     1    1    0    0    2    0    3    0    2    0    0    0    1    0
#     1    1    1]

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt #importing a module for plotting
# %matplotlib inline 
# this allows us to show graphs in a notebook

# Create the bins array
bins = []
length = len(count_consecutive_days)
for i in range(length):
    bins.append(i)
# print(bins)

# plt.hist(array, dividers/bins, alignment, graph color, border color)
plt.hist(consecutive_days_results,bins,align='left',color="yellow",edgecolor='k')

# Labels
plt.title("Number of Consecutive Days on Time")
plt.ylabel("Frequency")
plt.xlabel("Number of Consecutive Days")

plt.show()

# %% [markdown]
# ### "Grouped" Histogram

# %%
# Import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Create bins array
bins = []
for i in range(13):
    bin = i * 5
    bins.append(bin)
print(bins)

# Create title and lables
plt.title("Number of Consecutive Days on Time")
plt.ylabel("Frequency")
plt.xlabel("Number of Consecutive Days")

# plt.hist(array, dividers/bins, alignment, graph color, border color)
plt.hist(consecutive_days_results,bins,align="mid", color="lightgreen", edgecolor="black")

# Show
plt.show()
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# %% [markdown]
# # Answer
# * According to our simulation, my friend will show up an average of 5.75 days in a row befoore he/she arrives late.
